# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
"""
- Data may not always come in 1 huge file
- 5 million row dataset may be broken into
- 5 separate datasets
- Easier to store and share
- May have new data for each day
- Important to be able to combine then clean, or vice versa
"""

# %%
weather_p1 = pd.read_csv('weather_p1.csv', sep=',')
weather_p2 = pd.read_csv('weather_p2.csv', sep=',')

# %%
weather_p1.head()
# Out:
#         date element  value
# 0  1/30/2010    tmax   27.8
# 1  1/31/2010    tmin   14.5

# %%
weather_p2.head()
# Out:
#         date element  value
# 0  1/30/2010    tmax   27.3
# 1  1/31/2010    tmin   14.4

# %%
##Vamos a concatenar
concatenated = pd.concat([weather_p1, weather_p2])

# %%
print(concatenated)
# Out:
#         date element  value
# 0  1/30/2010    tmax   27.8
# 1  1/31/2010    tmin   14.5
# 0  1/30/2010    tmax   27.3
# 1  1/31/2010    tmin   14.4

# %%
##Localizar las de id 0 
concatenated = concatenated.loc[0, :]
print(concatenated)
# Out:
#         date element  value
# 0  1/30/2010    tmax   27.8
# 0  1/30/2010    tmax   27.3

# %%
pd.concat([weather_p1, weather_p2], ignore_index=True)
##ignorar el id de cada base, y enumerar el id
# Out:
#         date element  value
# 0  1/30/2010    tmax   27.8
# 1  1/31/2010    tmin   14.5
# 2  1/30/2010    tmax   27.3
# 3  1/31/2010    tmin   14.4

# %%
##Finding and concatenating data

# %%
"""
Leverage Python’s features with data cleaning in
pandas
● In order to concatenate DataFrames:
● They must be in a list
● Can individually load if there are a few datasets
● But what if there are thousands?
● Solution: glob function to find files based
on a pa!ern
"""

# %%
"""
Globbing
● Pa!ern matching for file names
● Wildcards: * ?
● Any csv file: *.csv
● Any single character: file_?.csv
● Returns a list of file names
● Can use this list to load into separate DataFrames
"""

# %%
"""
The plan
● Load files from globbing into pandas
● Add the DataFrames into a list
● Concatenate multiple datasets at once
"""

# %%
import glob

# %%
csv_files = glob.glob('*.csv')

# %%
print(csv_files)
# Out:
# ['literary_birth_rate.csv', 'literary_birth_rate_new.csv', 'tidy_sample.csv', 'tuburculosis.csv', 'wather_tidy.csv', 'weather_p1.csv', 'weather_p2.csv']

# %%
list_data = []
for filename in csv_files:
    data = pd.read_csv(filename)
    list_data.append(data)

# %%
pd.concat(list_data)
# Out:
# c:\users\b35205\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#     Continent                             Country  \
# 0         ASI                                 NaN
# 1         ASI                                 NaN
# 2         NAM                                 NaN
# 3         ASI                                 NaN
# 4         LAT                                 NaN
# 5         ASI                                 NaN
# 6         ASI                                 NaN
# 7          AF                                 NaN
# 8         EUR                                 NaN
# 9         ASI                                 NaN
# 10        LAT                                 NaN
# 11        ASI                                 NaN
# 12        ASI                                 NaN
# 13        EUR                                 NaN
# 14         AF                                 NaN
# 15         AF                                 NaN
# 16        ASI                                 NaN
# 17        ASI                                 NaN
# 18        ASI                                 NaN
# 19         AF                                 NaN
# 20        EUR                                 NaN
# 21        EUR                                 NaN
# 22        EUR                                 NaN
# 23        ASI                                 NaN
# 24         AF                                 NaN
# 25        ASI                                 NaN
# 26        EUR                                 NaN
# 27        EUR                                 NaN
# 28        LAT                                 NaN
# 29         AF                                 NaN
# ..        ...                                 ...
# 160       LAT                               Aruba
# 161       ASI                               Tonga
# 162       OCE                           Australia
# 163       NaN                  Antigua-et-Barbuda
# 164       NaN              Antilles néerlandaises
# 165       NaN                       Iles Caïmanes
# 166       NaN                          Seychelles
# 167       NaN  Territoires autonomes palestiniens
# 168     WORLD                               WORLD
# 0         NaN                                 NaN
# 1         NaN                                 NaN
# 2         NaN                                 NaN
# 3         NaN                                 NaN
# 4         NaN                                 NaN
# 5         NaN                                 NaN
# 0         NaN                                 NaN
# 1         NaN                                 NaN
# 2         NaN                                 NaN
# 0         NaN                                 NaN
# 1         NaN                                 NaN
# 2         NaN                                 NaN
# 3         NaN                                 NaN
# 4         NaN                                 NaN
# 5         NaN                                 NaN
# 6         NaN                                 NaN
# 7         NaN                                 NaN
# 0         NaN                                 NaN
# 1         NaN                                 NaN
# 0         NaN                                 NaN
# 1         NaN                                 NaN
#
#                           Country  country       date element  \
# 0                            Chine     NaN        NaN     NaN
# 1                             Inde     NaN        NaN     NaN
# 2                              USA     NaN        NaN     NaN
# 3                        Indonésie     NaN        NaN     NaN
# 4                           Brésil     NaN        NaN     NaN
# 5                         Pakistan     NaN        NaN     NaN
# 6                       Bangladesh     NaN        NaN     NaN
# 7                          Nigéria     NaN        NaN     NaN
# 8             Fédération de Russie     NaN        NaN     NaN
# 9                            Japan     NaN        NaN     NaN
# 10                         Mexique     NaN        NaN     NaN
# 11                     Philippines     NaN        NaN     NaN
# 12                        Viet Nam     NaN        NaN     NaN
# 13                         Germany     NaN        NaN     NaN
# 14                          Egypte     NaN        NaN     NaN
# 15                        Ethiopie     NaN        NaN     NaN
# 16                         Turquie     NaN        NaN     NaN
# 17   Iran, République islamique d'     NaN        NaN     NaN
# 18                       Thaïlande     NaN        NaN     NaN
# 19      Rép. Démocratique du Congo     NaN        NaN     NaN
# 20                          France     NaN        NaN     NaN
# 21                              UK     NaN        NaN     NaN
# 22                          Italie     NaN        NaN     NaN
# 23                         Myanmar     NaN        NaN     NaN
# 24                  Afrique du Sud     NaN        NaN     NaN
# 25                     South Korea     NaN        NaN     NaN
# 26                         Ukraine     NaN        NaN     NaN
# 27                         Espagne     NaN        NaN     NaN
# 28                        Colombie     NaN        NaN     NaN
# 29     République-Unie de Tanzanie     NaN        NaN     NaN
# ..                             ...     ...        ...     ...
# 160                            NaN     NaN        NaN     NaN
# 161                            NaN     NaN        NaN     NaN
# 162                            NaN     NaN        NaN     NaN
# 163                            NaN     NaN        NaN     NaN
# 164                            NaN     NaN        NaN     NaN
# 165                            NaN     NaN        NaN     NaN
# 166                            NaN     NaN        NaN     NaN
# 167                            NaN     NaN        NaN     NaN
# 168                            NaN     NaN        NaN     NaN
# 0                              NaN     NaN        NaN     NaN
# 1                              NaN     NaN        NaN     NaN
# 2                              NaN     NaN        NaN     NaN
# 3                              NaN     NaN        NaN     NaN
# 4                              NaN     NaN        NaN     NaN
# 5                              NaN     NaN        NaN     NaN
# 0                              NaN      AD        NaN     NaN
# 1                              NaN      AE        NaN     NaN
# 2                              NaN      AF        NaN     NaN
# 0                              NaN     NaN        NaN     NaN
# 1                              NaN     NaN        NaN     NaN
# 2                              NaN     NaN        NaN     NaN
# 3                              NaN     NaN        NaN     NaN
# 4                              NaN     NaN        NaN     NaN
# 5                              NaN     NaN        NaN     NaN
# 6                              NaN     NaN        NaN     NaN
# 7                              NaN     NaN        NaN     NaN
# 0                              NaN     NaN  1/30/2010    tmax
# 1                              NaN     NaN  1/31/2010    tmin
# 0                              NaN     NaN  1/30/2010    tmax
# 1                              NaN     NaN  1/31/2010    tmin
#
#      fecha;elemento;valor  female literacy fertility  m014  m1524  \
# 0                     NaN             90.5     1.769   NaN    NaN
# 1                     NaN             50.8     2.682   NaN    NaN
# 2                     NaN             99.0     2.077   NaN    NaN
# 3                     NaN             88.8     2.132   NaN    NaN
# 4                     NaN             90.2     1.827   NaN    NaN
# 5                     NaN             40.0     3.872   NaN    NaN
# 6                     NaN             49.8     2.288   NaN    NaN
# 7                     NaN             48.8     5.173   NaN    NaN
# 8                     NaN             99.4     1.393   NaN    NaN
# 9                     NaN             99.0     1.262   NaN    NaN
# 10                    NaN             91.5     2.156   NaN    NaN
# 11                    NaN             93.9     3.026   NaN    NaN
# 12                    NaN             90.2     2.033   NaN    NaN
# 13                    NaN             99.0     1.324   NaN    NaN
# 14                    NaN             57.8     2.816   NaN    NaN
# 15                    NaN             22.8     5.211   NaN    NaN
# 16                    NaN             81.3       2.1   NaN    NaN
# 17                    NaN             77.2     1.781   NaN    NaN
# 18                    NaN             91.5     1.822   NaN    NaN
# 19                    NaN             56.1     5.908   NaN    NaN
# 20                    NaN             99.0     1.881   NaN    NaN
# 21                    NaN             99.0     1.852   NaN    NaN
# 22                    NaN             98.5      1.39   NaN    NaN
# 23                    NaN             89.2     2.281   NaN    NaN
# 24                    NaN             88.1     2.505   NaN    NaN
# 25                    NaN             96.6     1.224   NaN    NaN
# 26                    NaN             99.6     1.361   NaN    NaN
# 27                    NaN             96.9     1.468   NaN    NaN
# 28                    NaN             93.4     2.404   NaN    NaN
# 29                    NaN             66.3      5.52   NaN    NaN
# ..                    ...              ...       ...   ...    ...
# 160                   NaN             98.0     1.732   NaN    NaN
# 161                   NaN             99.1     3.928   NaN    NaN
# 162                   NaN             96.0      1.93   NaN    NaN
# 163                   NaN             99.4   missing   NaN    NaN
# 164                   NaN             96.3   missing   NaN    NaN
# 165                   NaN             99.0   missing   NaN    NaN
# 166                   NaN             92.3   missing   NaN    NaN
# 167                   NaN             90.9   missing   NaN    NaN
# 168                   NaN             77.0       NaN   NaN    NaN
# 0                     NaN              NaN       NaN   NaN    NaN
# 1                     NaN              NaN       NaN   NaN    NaN
# 2                     NaN              NaN       NaN   NaN    NaN
# 3                     NaN              NaN       NaN   NaN    NaN
# 4                     NaN              NaN       NaN   NaN    NaN
# 5                     NaN              NaN       NaN   NaN    NaN
# 0                     NaN              NaN       NaN   0.0    0.0
# 1                     NaN              NaN       NaN   2.0    4.0
# 2                     NaN              NaN       NaN  52.0  228.0
# 0    30/01/2019;tmin;32.5              NaN       NaN   NaN    NaN
# 1    30/01/2019;tmax;23.4              NaN       NaN   NaN    NaN
# 2     1/02/2019;tmin;12.3              NaN       NaN   NaN    NaN
# 3     1/02/2019;tmax;54.2              NaN       NaN   NaN    NaN
# 4     2/02/2019;tmin;11.3              NaN       NaN   NaN    NaN
# 5     2/02/2019;tmax;13.6              NaN       NaN   NaN    NaN
# 6     9/02/2019;tmin;13.1              NaN       NaN   NaN    NaN
# 7      9/02/2019;tmax;9.2              NaN       NaN   NaN    NaN
# 0                     NaN              NaN       NaN   NaN    NaN
# 1                     NaN              NaN       NaN   NaN    NaN
# 0                     NaN              NaN       NaN   NaN    NaN
# 1                     NaN              NaN       NaN   NaN    NaN
#
#     nombre;emp1;emp2     population  value    year
# 0                NaN  1,324,655,000    NaN     NaN
# 1                NaN  1,139,964,932    NaN     NaN
# 2                NaN    304,060,000    NaN     NaN
# 3                NaN    227,345,082    NaN     NaN
# 4                NaN    191,971,506    NaN     NaN
# 5                NaN    166,111,487    NaN     NaN
# 6                NaN    160,000,128    NaN     NaN
# 7                NaN    151,212,254    NaN     NaN
# 8                NaN    141,950,000    NaN     NaN
# 9                NaN    127,704,000    NaN     NaN
# 10               NaN    106,350,434    NaN     NaN
# 11               NaN     90,348,437    NaN     NaN
# 12               NaN     86,210,781    NaN     NaN
# 13               NaN     82,110,097    NaN     NaN
# 14               NaN     81,527,172    NaN     NaN
# 15               NaN     80,713,434    NaN     NaN
# 16               NaN     73,914,260    NaN     NaN
# 17               NaN     71,956,322    NaN     NaN
# 18               NaN     67,386,383    NaN     NaN
# 19               NaN     64,256,635    NaN     NaN
# 20               NaN     62,277,432    NaN     NaN
# 21               NaN     61,414,062    NaN     NaN
# 22               NaN     59,832,179    NaN     NaN
# 23               NaN     49,563,019    NaN     NaN
# 24               NaN     48,687,000    NaN     NaN
# 25               NaN     48,607,000    NaN     NaN
# 26               NaN     46,258,200    NaN     NaN
# 27               NaN     45,555,716    NaN     NaN
# 28               NaN     45,012,096    NaN     NaN
# 29               NaN     42,483,923    NaN     NaN
# ..               ...            ...    ...     ...
# 160              NaN         105455    NaN     NaN
# 161              NaN         103566    NaN     NaN
# 162              NaN      2.313e+09    NaN     NaN
# 163              NaN            NaN    NaN     NaN
# 164              NaN            NaN    NaN     NaN
# 165              NaN            NaN    NaN     NaN
# 166              NaN            NaN    NaN     NaN
# 167              NaN            NaN    NaN     NaN
# 168              NaN            NaN    NaN     NaN
# 0         Jorge;23;5            NaN    NaN     NaN
# 1       Camila;12;10            NaN    NaN     NaN
# 2        Erison;54;2            NaN    NaN     NaN
# 3          Luis;12;1            NaN    NaN     NaN
# 4     Victoria;11;23            NaN    NaN     NaN
# 5        Cesar;10;32            NaN    NaN     NaN
# 0                NaN            NaN    NaN  2000.0
# 1                NaN            NaN    NaN  2000.0
# 2                NaN            NaN    NaN  2000.0
# 0                NaN            NaN    NaN     NaN
# 1                NaN            NaN    NaN     NaN
# 2                NaN            NaN    NaN     NaN
# 3                NaN            NaN    NaN     NaN
# 4                NaN            NaN    NaN     NaN
# 5                NaN            NaN    NaN     NaN
# 6                NaN            NaN    NaN     NaN
# 7                NaN            NaN    NaN     NaN
# 0                NaN            NaN   27.8     NaN
# 1                NaN            NaN   14.5     NaN
# 0                NaN            NaN   27.3     NaN
# 1                NaN            NaN   14.4     NaN
#
# [358 rows x 15 columns]

# %%
##Combining data
"""
Similar to joining tables in SQL
● Combine disparate datasets based on common columns
"""

# %%
pd.merge(left=state_populations, right=state_codes, 
         on=None, left_on='state', right_on='name')

# %%
"""
Types of merges
● One-to-one
● Many-to-one / one-to-many
● Many-to-many
"""
